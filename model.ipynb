# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split as tt
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression as LR
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score as acc

# %%
file = open("dummy.csv", "r")
file1 = open("data2.csv", "w")
file1.write('"Ping Local" "Ping LocalApp-CorpApp" "Ping LocalApp-CorpDB" "Load Average LocalApp" "Load Average LocalDB" "Load Average CORPApp" "TNS ping LocalApp-LocalDB" "TNS ping LocalApp-CorpDB" "Class"\n')
for line in file:
    l = len(line)
    dat = list(line.split())
    if (dat[1] == 'x' or dat[5] == 'x'):
        line = ""
        for da in dat:
            if (da == 'x'):
                da = '9999999999'
            line+=da+" "
        line += "1\n"
    elif (dat[2] == 'x' or dat[7] == 'x'):
        line = ""
        for da in dat:
            if (da == 'x'):
                da = '9999999999'
            line+=da+" "
        line += "2\n"
    elif (dat[3] == 'x' or dat[4] == 'x' or dat[6] == 'x'):
        line = ""
        for da in dat:
            if (da == 'x'):
                da = '9999999999'
            line+=da+" "
        line += "3\n"
    else:
        line = line[:-1] + " 0" + line[-1]
    file1.write(line)
file.close()
file1.close()

# %%
data = pd.read_csv("data2.csv",delimiter = ' ')
data
# Out:
#        Ping Local  Ping LocalApp-CorpApp  Ping LocalApp-CorpDB  \
# 0           0.412                   68.3                  55.2
# 1             NaN                    0.0                   NaN
# 2           0.474                   67.4                  54.9
# 3             NaN                    0.0                   NaN
# 4           0.422                   66.7                  55.4
# 5             NaN                    0.0                   NaN
# 6           0.586                   66.4                  55.3
# 7             NaN                    0.0                   NaN
# 8           0.489                   74.4                  55.2
# 9             NaN                    0.0                   NaN
# 10          0.383                   67.4                  56.5
# 11            NaN                    0.0                   NaN
# 12          0.434                   66.7                  56.4
# 13            NaN                    0.0                   NaN
# 14          0.304                   65.1                  56.9
# 15            NaN                    0.0                   NaN
# 16          0.363                   66.1                  56.6
# 17            NaN                    0.0                   NaN
# 18          0.398                   65.6                  56.1
# 19            NaN                    0.0                   NaN
# 20          0.454                   65.5                  56.2
# 21            NaN                    0.0                   NaN
# 22          0.405                   65.9                  56.6
# 23            NaN                    0.0                   NaN
# 24          0.359                   66.4                  56.8
# 25            NaN                    0.0                   NaN
# 26          0.330                   65.2                  59.2
# 27            NaN                    0.0                   NaN
# 28          0.402                   65.6                  57.0
# 29            NaN                    0.0                   NaN
# ...           ...                    ...                   ...
# 11641       1.700                   65.4                  56.2
# 11642       0.352                   64.2                  56.1
# 11643       2.560                   65.2                  55.8
# 11644       0.367                   64.4                  56.0
# 11645       0.349                   63.4                  52.7
# 11646       0.457                   64.3                  55.9
# 11647       0.361                   64.7                  56.2
# 11648       2.220                   65.4                  56.3
# 11649       0.377                   64.3                  55.9
# 11650       1.500                   61.5                  56.0
# 11651       0.376                   61.3                  56.1
# 11652       2.320                   61.6                  56.2
# 11653       2.760                   61.3                  93.4
# 11654       0.597                   61.5                  56.1
# 11655       2.270                   61.5                  56.1
# 11656       0.502                   61.2                  56.3
# 11657       1.490                   60.8                  56.0
# 11658       0.551                   60.9                  56.4
# 11659       1.750                   60.9                  56.3
# 11660       0.591                   61.0                  56.4
# 11661       2.180                   61.5                  55.9
# 11662       0.459                   61.0                  56.0
# 11663       1.940                   61.1                  56.2
# 11664       0.412                   61.3                  56.2
# 11665       2.470                   61.6                  58.5
# 11666       0.442                   61.2                  56.1
# 11667       1.700                   65.4                  56.2
# 11668       0.352                   64.2                  56.1
# 11669       2.560                   65.2                  55.8
# 11670       0.367                   64.4                  56.0
#
#        Load Average LocalApp  Load Average LocalDB  Load Average CORPApp  \
# 0                       0.21                  0.03                  0.39
# 1                        NaN                   NaN                   NaN
# 2                       0.22                  0.09                  0.92
# 3                        NaN                   NaN                   NaN
# 4                       0.47                  0.02                  0.81
# 5                        NaN                   NaN                   NaN
# 6                       0.88                  0.20                  0.47
# 7                        NaN                   NaN                   NaN
# 8                       0.30                  0.12                  0.46
# 9                        NaN                   NaN                   NaN
# 10                      1.26                  0.12                  0.55
# 11                       NaN                   NaN                   NaN
# 12                      0.20                  0.05                  0.24
# 13                       NaN                   NaN                   NaN
# 14                      0.53                  0.03                  1.98
# 15                       NaN                   NaN                   NaN
# 16                      0.58                  0.09                  0.64
# 17                       NaN                   NaN                   NaN
# 18                      0.25                  0.08                  0.47
# 19                       NaN                   NaN                   NaN
# 20                      0.19                  0.02                  0.30
# 21                       NaN                   NaN                   NaN
# 22                      0.72                  0.24                  0.46
# 23                       NaN                   NaN                   NaN
# 24                      0.34                  0.02                  0.44
# 25                       NaN                   NaN                   NaN
# 26                      0.57                  0.14                  0.82
# 27                       NaN                   NaN                   NaN
# 28                      0.16                  0.15                  0.26
# 29                       NaN                   NaN                   NaN
# ...                      ...                   ...                   ...
# 11641                   0.08                  0.00                  0.08
# 11642                   0.00                  0.00                  0.00
# 11643                   0.06                  0.00                  0.00
# 11644                   0.00                  3.68                  1.25
# 11645                   0.00                  0.00                  1.70
# 11646                   0.07                  0.02                  0.08
# 11647                   0.00                  0.06                  0.00
# 11648                   0.00                  0.00                  0.00
# 11649                   0.00                  0.00                  0.08
# 11650                   0.09                  0.00                  0.00
# 11651                   0.00                  0.01                  0.00
# 11652                   0.17                  0.05                  0.00
# 11653                   0.06                  0.00                  0.00
# 11654                   0.00                  0.00                  0.00
# 11655                   0.08                  0.01                  0.08
# 11656                   0.00                  0.01                  0.00
# 11657                   0.02                  0.01                  0.09
# 11658                   0.00                  0.03                  0.00
# 11659                   0.03                  0.00                  0.08
# 11660                   0.00                  0.17                  0.00
# 11661                   0.05                  0.12                  0.00
# 11662                   0.00                  0.14                  0.00
# 11663                   0.04                  0.00                  0.00
# 11664                   0.00                  0.01                  0.00
# 11665                   0.07                  0.04                  0.35
# 11666                   0.00                  0.01                  0.05
# 11667                   0.08                  0.00                  0.08
# 11668                   0.00                  0.00                  0.00
# 11669                   0.06                  0.00                  0.00
# 11670                   0.00                  3.68                  1.25
#
#        TNS ping LocalApp-LocalDB  TNS ping LocalApp-CorpDB  Class
# 0                   0.000000e+00              1.200000e+02    NaN
# 1                            NaN                       NaN    NaN
# 2                   0.000000e+00              1.200000e+02    NaN
# 3                            NaN                       NaN    NaN
# 4                   0.000000e+00              1.300000e+02    NaN
# 5                            NaN                       NaN    NaN
# 6                   0.000000e+00              1.300000e+02    NaN
# 7                            NaN                       NaN    NaN
# 8                   0.000000e+00              1.300000e+02    NaN
# 9                            NaN                       NaN    NaN
# 10                  0.000000e+00              1.200000e+02    NaN
# 11                           NaN                       NaN    NaN
# 12                  0.000000e+00              1.300000e+02    NaN
# 13                           NaN                       NaN    NaN
# 14                  0.000000e+00              1.200000e+02    NaN
# 15                           NaN                       NaN    NaN
# 16                  0.000000e+00              1.300000e+02    NaN
# 17                           NaN                       NaN    NaN
# 18                  0.000000e+00              1.200000e+02    NaN
# 19                           NaN                       NaN    NaN
# 20                  0.000000e+00              1.200000e+02    NaN
# 21                           NaN                       NaN    NaN
# 22                  0.000000e+00              1.200000e+02    NaN
# 23                           NaN                       NaN    NaN
# 24                  1.000000e+01              1.200000e+02    NaN
# 25                           NaN                       NaN    NaN
# 26                  0.000000e+00              1.300000e+02    NaN
# 27                           NaN                       NaN    NaN
# 28                  0.000000e+00              1.300000e+02    NaN
# 29                           NaN                       NaN    NaN
# ...                          ...                       ...    ...
# 11641               1.000000e+10              1.300000e+02    3.0
# 11642               1.000000e+10              1.200000e+02    3.0
# 11643               1.000000e+10              1.300000e+02    3.0
# 11644               1.000000e+10              1.200000e+02    3.0
# 11645               0.000000e+00              1.000000e+10    2.0
# 11646               1.000000e+01              1.000000e+10    2.0
# 11647               1.000000e+10              1.000000e+10    2.0
# 11648               1.000000e+10              1.000000e+10    2.0
# 11649               1.000000e+10              1.000000e+10    2.0
# 11650               1.000000e+10              1.000000e+10    2.0
# 11651               1.000000e+10              1.000000e+10    2.0
# 11652               1.000000e+10              1.000000e+10    2.0
# 11653               1.000000e+10              1.000000e+10    2.0
# 11654               1.000000e+10              1.000000e+10    2.0
# 11655               1.000000e+10              1.000000e+10    2.0
# 11656               1.000000e+10              1.000000e+10    2.0
# 11657               1.000000e+10              1.000000e+10    2.0
# 11658               1.000000e+10              1.000000e+10    2.0
# 11659               1.000000e+10              1.000000e+10    2.0
# 11660               1.000000e+10              1.000000e+10    2.0
# 11661               1.000000e+10              1.000000e+10    2.0
# 11662               1.000000e+10              1.000000e+10    2.0
# 11663               1.000000e+10              1.000000e+10    2.0
# 11664               1.000000e+10              1.000000e+10    2.0
# 11665               1.000000e+10              1.000000e+10    2.0
# 11666               1.000000e+10              1.000000e+10    2.0
# 11667               1.000000e+10              1.300000e+02    3.0
# 11668               1.000000e+10              1.200000e+02    3.0
# 11669               1.000000e+10              1.300000e+02    3.0
# 11670               1.000000e+10              1.200000e+02    3.0
#
# [11671 rows x 9 columns]

# %%
x = data.ix[:,:8]
y = data.ix[:,8:]
x_train,x_test,y_train,y_test = tt(x,y,test_size=0.4,random_state=1)
y_train
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
#        Class
# 9996     NaN
# 1599     NaN
# 11045    2.0
# 6261     NaN
# 2345     2.0
# 7415     NaN
# 3187     NaN
# 3121     NaN
# 2695     NaN
# 10170    NaN
# 4313     NaN
# 5684     NaN
# 11076    2.0
# 4344     NaN
# 9834     NaN
# 7911     NaN
# 5401     NaN
# 9652     NaN
# 10709    2.0
# 10130    NaN
# 9999     2.0
# 7107     NaN
# 7023     NaN
# 6940     NaN
# 4266     2.0
# 5395     NaN
# 8637     NaN
# 5664     NaN
# 7754     NaN
# 1831     NaN
# ...      ...
# 1110     NaN
# 1888     NaN
# 9719     2.0
# 753      NaN
# 3049     NaN
# 8151     NaN
# 10820    2.0
# 562      NaN
# 6542     NaN
# 8093     NaN
# 4764     NaN
# 3562     NaN
# 8444     NaN
# 2516     NaN
# 2962     NaN
# 5374     NaN
# 5396     NaN
# 9394     NaN
# 3462     NaN
# 10989    2.0
# 7751     NaN
# 4225     NaN
# 144      2.0
# 5056     2.0
# 2895     NaN
# 7813     NaN
# 10955    2.0
# 905      NaN
# 5192     NaN
# 235      2.0
#
# [7002 rows x 1 columns]

# %%
clf = RandomForestClassifier(n_estimators = 500)
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-321ced3aa002> in <module>()
#       1 clf = RandomForestClassifier(n_estimators = 500)
# ----> 2 clf.fit(x_train,y_train)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if issparse(X):
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
result = clf.predict(x_test)
prob = clf.predict_proba(x_test)
print (result)
print (str((acc(y_test,result)*100).astype(int),) + "% accurate")
np.savetxt("output.csv", result , delimiter=" ",fmt= "%0.0f")
print (prob)
